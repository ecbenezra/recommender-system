# %% [markdown]
# # The Hybrid Recommender System
#
# This system joins together our content based and collaborative recommender system through the following format:
#
# 1. Load the datasets and merge them together where need be
# 2. Select out movies in the ratings dataset that are also in the dataset for content-based filtering
# 3. When a user searches for a specific movie, they will be returned 'similar movies', ordered by their estimated rating of the movie.
#
# I will be including movies that I have rated that are within the system, as well.

# %%
# import statements

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import random

from surprise import Reader, Dataset, SVD, evaluate, accuracy
from surprise.model_selection import GridSearchCV, KFold, train_test_split
from surprise.model_selection.validation import cross_validate
from surprise.prediction_algorithms.matrix_factorization import SVDpp

import nltk
from rake_nltk import Rake
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

import time

import warnings; warnings.simplefilter('ignore')


# %matplotlib inline

# %%
# Load our datasets

# Ratings dataset from MovieLens 20M
ratings = pd.read_csv('/Users/user/movielens-20m-dataset/rating.csv')

# Our information from our scraped dataset
movies = pd.read_csv('/Users/user/final-capstone/inprogress3.csv')

# Links dataset from MovieLens, which we will hopefully use to knit together the two datasets
links = pd.read_csv('/Users/user/movielens-20m-dataset/link.csv')

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
unique_movs = ratings['movieId'].unique().shape[0]
unique_movs
# Out:
# 26744

# %%
movies.shape
# Out:
# (284303, 25)

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links.shape
# Out:
# (27278, 3)

# %%
movies.columns
# Out:
# Index(['title', 'year', 'rated', 'released', 'runtime', 'genre', 'director',
#        'writer', 'actors', 'plot', 'language', 'country', 'awards', 'poster',
#        'ratings', 'metascore', 'imdb_rating', 'imdb_votes', 'imdb_id', 'type',
#        'dvd', 'box_office', 'production', 'website', 'response'],
#       dtype='object')

# %%
movies = movies[['title','year','rated','imdb_id', 'genre', 'director','writer','actors','plot','language','country']]

movies.head()
# Out:
#                          title  year  rated    imdb_id  \
# 0                    Toy Story  1995      G  tt0114709
# 1                      Jumanji  1995     PG  tt0113497
# 2             Grumpier Old Men  1995  PG-13  tt0113228
# 3            Waiting to Exhale  1995      R  tt0114885
# 4  Father of the Bride Part II  1995     PG  tt0113041
#
#                                            genre         director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2  Mark Steven Johnson (characters), Mark Steven ...
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                    language country
# 0                   English     USA
# 1           English, French     USA
# 2  English, Italian, German     USA
# 3                   English     USA
# 4                   English     USA

# %%
movies['imdb_id'] = movies['imdb_id'].str.replace('tt0','')
movies['imdb_id'] = movies['imdb_id'].str.replace('tt','')

# %%
movies = movies.dropna(subset=['imdb_id'],axis=0)
movies['imdb_id'].isnull().value_counts()
# Out:
# False    277321
# Name: imdb_id, dtype: int64

# %%
movies['imdb_id'] = movies['imdb_id'].astype('int')

# %%
movies.columns = ['title','year','rated','imdbId', 'genre', 'director','writer','actors','plot','language','country']
movies.head()
# Out:
#                          title  year  rated  imdbId  \
# 0                    Toy Story  1995      G  114709
# 1                      Jumanji  1995     PG  113497
# 2             Grumpier Old Men  1995  PG-13  113228
# 3            Waiting to Exhale  1995      R  114885
# 4  Father of the Bride Part II  1995     PG  113041
#
#                                            genre         director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2  Mark Steven Johnson (characters), Mark Steven ...
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                    language country
# 0                   English     USA
# 1           English, French     USA
# 2  English, Italian, German     USA
# 3                   English     USA
# 4                   English     USA

# %%
movies = pd.merge(movies,links,on='imdbId')
movies.head()
# Out:
#                          title  year  rated  imdbId  \
# 0                    Toy Story  1995      G  114709
# 1                      Jumanji  1995     PG  113497
# 2             Grumpier Old Men  1995  PG-13  113228
# 3            Waiting to Exhale  1995      R  114885
# 4  Father of the Bride Part II  1995     PG  113041
#
#                                            genre         director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2  Mark Steven Johnson (characters), Mark Steven ...
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                    language country  movieId   tmdbId
# 0                   English     USA        1    862.0
# 1           English, French     USA        2   8844.0
# 2  English, Italian, German     USA        3  15602.0
# 3                   English     USA        4  31357.0
# 4                   English     USA        5  11862.0

# %%
movies['year'] = movies['year'].apply(lambda x: str(x))
movies['title_year'] = movies['title'].map(str) + ' (' + movies['year'] + ')'
movies = movies[['title_year','rated','imdbId','genre','director','writer','actors','plot','language','country',
                 'movieId','tmdbId', 'year']]
movies.head()
# Out:
#                            title_year  rated  imdbId  \
# 0                    Toy Story (1995)      G  114709
# 1                      Jumanji (1995)     PG  113497
# 2             Grumpier Old Men (1995)  PG-13  113228
# 3            Waiting to Exhale (1995)      R  114885
# 4  Father of the Bride Part II (1995)     PG  113041
#
#                                            genre         director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2  Mark Steven Johnson (characters), Mark Steven ...
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                    language country  movieId   tmdbId  year
# 0                   English     USA        1    862.0  1995
# 1           English, French     USA        2   8844.0  1995
# 2  English, Italian, German     USA        3  15602.0  1995
# 3                   English     USA        4  31357.0  1995
# 4                   English     USA        5  11862.0  1995

# %%
movies.shape
# Out:
# (28047, 13)

# %%
# Make a copy of the movies dataframe before we process the text for our final product

callback = movies.copy()

# %%
extras = movies[['title_year','imdbId','movieId','tmdbId']]
extras.head()
# Out:
#                            title_year  imdbId  movieId   tmdbId
# 0                    Toy Story (1995)  114709        1    862.0
# 1                      Jumanji (1995)  113497        2   8844.0
# 2             Grumpier Old Men (1995)  113228        3  15602.0
# 3            Waiting to Exhale (1995)  114885        4  31357.0
# 4  Father of the Bride Part II (1995)  113041        5  11862.0

# %%
movies = movies[['title_year','rated','writer','genre','director','actors','plot','language','country', 'year']]

for column in movies:
    movies[column] = movies[column].apply(lambda x: str(x))
    
# discarding the commas between the actors' full names
movies['actors'] = movies['actors'].map(lambda x: x.split(','))

# putting the genres in a list of words
movies['genre'] = movies['genre'].map(lambda x: x.lower().split(','))

#movies['director'] = movies['director'].apply(lambda x: [x,x,x])

movies['director'] = movies['director'].map(lambda x: x.split(','))


# merging together first and last name for each actor and director, so it's considered as one word 
# and there is no mix up between people sharing a first name
for index, row in movies.iterrows():
    row['actors'] = [x.lower().replace(' ','') for x in row['actors']]
    row['director'] = [x.lower().replace(' ','') for x in row['director']]


# Getting rid of information between () in writers
movies['writer'] = movies['writer'].str.replace(r"\(.*\)","")

# discarding the commas between writer's names
movies['writer'] = movies['writer'].map(lambda x: x.split(','))

# putting the countries in a list of words
movies['country'] = movies['country'].map(lambda x: x.lower().split(','))

# putting the languages in a list of words
movies['language'] = movies['language'].map(lambda x: x.lower().split(','))

movies['rated'] = movies['rated'].str.replace("-","")
movies['rated'] = movies['rated'].apply(lambda x: str(x))
movies['rated'] = movies['rated'].apply(lambda x: [x,x] if x == 'G' or x == 'PG' else x.split(','))

movies['year'] = movies['year'].map(lambda x: x.split(','))

# merging together first and last name for each actor and director, so it's considered as one word 
# and there is no mix up between people sharing a first name
for index, row in movies.iterrows():
    row['writer'] = [x.lower().replace(' ','') for x in row['writer']]
    row['rated'] = [x.lower().replace(' ','') for x in row['rated']]

movies.head()
# Out:
#                            title_year     rated  \
# 0                    Toy Story (1995)    [g, g]
# 1                      Jumanji (1995)  [pg, pg]
# 2             Grumpier Old Men (1995)    [pg13]
# 3            Waiting to Exhale (1995)       [r]
# 4  Father of the Bride Part II (1995)  [pg, pg]
#
#                                    writer  \
# 0                          [johnlasseter]
# 1                     [jonathanhensleigh]
# 2  [markstevenjohnson, markstevenjohnson]
# 3                         [terrymcmillan]
# 4                         [alberthackett]
#
#                                                genre          director  \
# 0  [animation,  adventure,  comedy,  family,  fan...    [johnlasseter]
# 1            [adventure,  comedy,  family,  fantasy]     [joejohnston]
# 2                                 [comedy,  romance]    [howarddeutch]
# 3                         [comedy,  drama,  romance]  [forestwhitaker]
# 4                        [comedy,  family,  romance]    [charlesshyer]
#
#                                               actors  \
# 0        [tomhanks, timallen, donrickles, jimvarney]
# 1  [robinwilliams, jonathanhyde, kirstendunst, br...
# 2  [waltermatthau, jacklemmon, sophialoren, ann-m...
# 3  [whitneyhouston, angelabassett, lorettadevine,...
# 4  [stevemartin, dianekeaton, martinshort, kimber...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                        language country    year
# 0                     [english]   [usa]  [1995]
# 1            [english,  french]   [usa]  [1995]
# 2  [english,  italian,  german]   [usa]  [1995]
# 3                     [english]   [usa]  [1995]
# 4                     [english]   [usa]  [1995]

# %%
# initializing the new column
movies['Key_words'] = ""

for index, row in movies.iterrows():
    plot = row['plot']
    
    # instantiating Rake, by default is uses english stopwords from NLTK
    # and discard all puntuation characters
    r = Rake()

    # extracting the words by passing the text
    r.extract_keywords_from_text(plot)

    # getting the dictionary whith key words and their scores
    key_words_dict_scores = r.get_word_degrees()
    
    # assigning the key words to the new column
    row['Key_words'] = list(key_words_dict_scores.keys())

# dropping the Plot column
movies.drop(columns = ['plot'], inplace = True)

movies.shape
# Out:
# (28047, 10)

# %%
movies.set_index('title_year', inplace = True)

movies['bag_of_words'] = ''
columns = movies.columns
for index, row in movies.iterrows():
    words = ''
    for col in columns:
        #if col == 'director':
        #    words = words.join(row[col]) + ' '
        #else:
        words = words + ' '.join(row[col])+ ' '

    row['bag_of_words'] = words
    
movies.drop(columns = [col for col in movies.columns if col!= 'bag_of_words'], inplace = True)

movies['bag_of_words'] = movies['bag_of_words'].str.replace('nan','')

movies.head()
# Out:
#                                                                          bag_of_words
# title_year
# Toy Story (1995)                    g g johnlasseter animation  adventure  comedy ...
# Jumanji (1995)                      pg pg jonathanhensleigh adventure  comedy  fam...
# Grumpier Old Men (1995)             pg13 markstevenjohnson markstevenjohnson comed...
# Waiting to Exhale (1995)            r terrymcmillan comedy  drama  romance forestw...
# Father of the Bride Part II (1995)  pg pg alberthackett comedy  family  romance ch...

# %%
movies = pd.merge(movies, extras, on='title_year')
movies.head()
# Out:
#                            title_year  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         bag_of_words  imdbId  movieId   tmdbId
# 0  g g johnlasseter animation  adventure  comedy ...  114709        1    862.0
# 1  pg pg jonathanhensleigh adventure  comedy  fam...  113497        2   8844.0
# 2  pg13 markstevenjohnson markstevenjohnson comed...  113228        3  15602.0
# 3  r terrymcmillan comedy  drama  romance forestw...  114885        4  31357.0
# 4  pg pg alberthackett comedy  family  romance ch...  113041        5  11862.0

# %%
movies = movies.drop_duplicates(subset='movieId')
movies.shape
# Out:
# (26701, 5)

# %%
ratings = ratings.drop('timestamp',axis=1)

# %%
movie_titles = movies[['title_year','movieId']]
movie_titles.head(1)
# Out:
#          title_year  movieId
# 0  Toy Story (1995)        1

# %%
ratings = pd.merge(ratings,movie_titles,on='movieId')
ratings.head(5)
# Out:
#    userId  movieId  rating      title_year
# 0       1        2     3.5  Jumanji (1995)
# 1       5        2     3.0  Jumanji (1995)
# 2      13        2     3.0  Jumanji (1995)
# 3      29        2     3.0  Jumanji (1995)
# 4      34        2     3.0  Jumanji (1995)

# %%
# hooray

# %% [markdown]
# # 1. Creating the similarity matrix for movie content
#
# Since creating the content recommender is the most computationally intensive and the most likely to overload my machine (though it shouldn't be as huge a problem with only 28k movies) I will calculate that first.

# %%
movies = movies.drop_duplicates(subset='movieId')
movies.shape
# Out:
# (26701, 5)

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(movies['bag_of_words'])

# %%
movies = movies.set_index('title_year')
# creating a Series for the movie titles so they are associated to an ordered numerical
# list I will use later to match the indexes
indices = pd.Series(movies.index)
indices[:5]
# Out:
# 0                      Toy Story (1995)
# 1                        Jumanji (1995)
# 2               Grumpier Old Men (1995)
# 3              Waiting to Exhale (1995)
# 4    Father of the Bride Part II (1995)
# Name: title_year, dtype: object

# %%
start = time.time()

cosine_sim = cosine_similarity(count_matrix, count_matrix)
cos_sim_time = time.time() - start

print("Runtime %0.2f" % (time.time() - start))
print(cosine_sim)
# Out:
# Runtime 37.12
# [[1.         0.22627786 0.15694121 ... 0.03390318 0.0758098  0.        ]
#  [0.22627786 1.         0.11769798 ... 0.03178209 0.07106691 0.        ]
#  [0.15694121 0.11769798 1.         ... 0.         0.06900656 0.        ]
#  ...
#  [0.03390318 0.03178209 0.         ... 1.         0.         0.24494897]
#  [0.0758098  0.07106691 0.06900656 ... 0.         1.         0.18257419]
#  [0.         0.         0.         ... 0.24494897 0.18257419 1.        ]]

# %%
# function that takes in movie title as input and returns the top 10 recommended movies
def recommendations(title, cosine_sim = cosine_sim):
    
    recommended_movies = []
    
    # gettin the index of the movie that matches the title
    idx = indices[indices == title].index[0]

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(cosine_sim[idx]).sort_values(ascending = False)

    # getting the indexes of the 10 most similar movies
    ordered_indices = list(score_series.iloc[1:100].index)
    
    # populating the list with the titles of the best 15 matching movies
    for i in ordered_indices:
        recommended_movies.append(list(movies.index)[i])
        
    return recommended_movies

# %%
def return_recs(title, df, n, orderby=None):
    title_a = recommendations(title)
    title_recs = df.loc[title_a].reset_index(inplace=False)
    title_recs = title_recs.set_index('title_year')
    
    print("Here are the movie recommendations for {}: ".format(title))
    if orderby == None:
        if n != 0:
            return title_recs[['rated','genre','director','plot','language','year','movieId']].head(n)
        else:
            return title_recs[['rated','genre','director','plot','language','year','movieId']]
        
    else:
        if n!= 0:
            title_recs = title_recs.sort_values(by=[orderby], ascending=False)
            return title_recs[['rated','genre','director','plot','language','year','movieId']].head(n)
        else:
            title_recs = title_recs.sort_values(by=[orderby], ascending=False)
            return title_recs[['rated','genre','director','plot','language','year','movieId']]

# %%
test = test.drop_duplicates(subset='movieId')

# %% [markdown]
# # 2. Training the SVD model

# %%
reader = Reader(rating_scale=(1, 5))

# %%
ratings.head()
# Out:
#    userId  movieId  rating      title_year
# 0       1        2     3.5  Jumanji (1995)
# 1       5        2     3.0  Jumanji (1995)
# 2      13        2     3.0  Jumanji (1995)
# 3      29        2     3.0  Jumanji (1995)
# 4      34        2     3.0  Jumanji (1995)

# %%
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# %%
# define a cross-validation iterator

start = time.time()

kf = KFold(n_splits=5)

algo = SVD(verbose=True)

for trainset, testset in kf.split(data):

    # train and test algorithm.
    algo.fit(trainset)
    predictions = algo.test(testset)

    # Compute and print Root Mean Squared Error
    accuracy.rmse(predictions, verbose=True)
    
print("Runtime %0.2f" % (time.time() - start))
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# RMSE: 0.7859
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# RMSE: 0.7870
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# RMSE: 0.7857
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# RMSE: 0.7857
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 5
# Processing epoch 6
# Processing epoch 7
# Processing epoch 8
# Processing epoch 9
# Processing epoch 10
# Processing epoch 11
# Processing epoch 12
# Processing epoch 13
# Processing epoch 14
# Processing epoch 15
# Processing epoch 16
# Processing epoch 17
# Processing epoch 18
# Processing epoch 19
# RMSE: 0.7867
# Runtime 5176.59

# %%
ratings.head()
# Out:
#    userId  movieId  rating      title_year
# 0       1        2     3.5  Jumanji (1995)
# 1       5        2     3.0  Jumanji (1995)
# 2      13        2     3.0  Jumanji (1995)
# 3      29        2     3.0  Jumanji (1995)
# 4      34        2     3.0  Jumanji (1995)

# %%
def check_system(Id,movieId,limit,df=ratings,userId='userId',algo=algo):
    '''
    This function checks the predicted rating against ratings made by the user
    And takes in an int UserId (Id)
    an int limit (the number of movies returned)
    dataframe columns necessary (movieId, userId)
    a dataframe of ratings (df)
    an algorithm (algo)
    '''
    
    # Takes a subsample of the user's ratings
    user_df = df[df['userId'] == Id]
    if user_df.shape[0] >= df[userId].value_counts().mean():
        user_df = user_df.sample(frac=.10)
    else:
        user_df = user_df.sample(frac=.50)

    # Builds the dataframe to be returned     
    user_df['est'] = user_df['movieId'].apply(lambda x: round(algo.predict(Id,x).est,2))
    user_df['error'] = user_df['est']-user_df['rating']
    user_df['avg_error'] = user_df['error'].mean()
    
    # Returns a dataframe dependent on what the limit is set to
    if limit == None:
        return user_df[[userId,movieId,'title_year','rating','est','error','avg_error']]
    else:
        if limit >= user_df.shape[0]:
            return user_df[[userId,movieId,'title_year','rating','est','error','avg_error']]
        else:
            user_df = user_df.head(limit)
            return user_df[[userId,movieId,'title_year','rating','est','error','avg_error']]

# %%
check_system(345,'movieId',10)
# Out:
#          userId  movieId                                         title_year  \
# 190561      345      223                                      Clerks (1994)
# 8470977     345     2355                                A Bug's Life (1998)
# 3705786     345     1220                          The Blues Brothers (1980)
# 6252071     345     1101                                     Top Gun (1986)
# 7889371     345     1923                There's Something About Mary (1998)
# 3725625     345     1221                      The Godfather: Part II (1974)
# 6121931     345      750  Dr. Strangelove or: How I Learned to Stop Worr...
# 1737724     345     2716                                Ghostbusters (1984)
# 7047883     345     3793                                       X-Men (2000)
# 8375781     345     1961                                    Rain Man (1988)
#
#          rating   est  error  avg_error
# 190561      3.0  3.17   0.17     -0.138
# 8470977     3.5  3.26  -0.24     -0.138
# 3705786     3.5  3.31  -0.19     -0.138
# 6252071     3.0  3.14   0.14     -0.138
# 7889371     3.0  3.34   0.34     -0.138
# 3725625     4.0  4.06   0.06     -0.138
# 6121931     5.0  3.68  -1.32     -0.138
# 1737724     4.0  3.46  -0.54     -0.138
# 7047883     4.0  3.61  -0.39     -0.138
# 8375781     3.0  3.59   0.59     -0.138

# %%
def predicted_top_n(Id, movieId, n, samples, df=ratings, userId='userId', algo=algo):
    '''
    This function returns n movies, sorted by predicted user rating, from a random sample of movies. 
    '''
    #df = df[[movieId,userId,'rating']]

    movie_choices = df[movieId].unique()
    
    # Take out movies the user has already watched
    temp_df = df[df[userId] == Id]
    watched_movs = temp_df[movieId].unique()
    unwatched = np.setdiff1d(movie_choices,watched_movs)
    
    # Select random movies according to 'samples'
    if samples == None:
        movs = unwatched
        samples = movs.shape[0]
    elif samples <= unwatched.shape[0]:
         movs = np.random.choice(unwatched,samples)
    else:
        print("The sample size exceeds the available movies. Reset to {} movies".format(unwatched.shape[0]))
        movs = unwatched
        samples = movs.shape[0]
        
    # Build the dataframe that we'll return
    predicted_df = pd.DataFrame()
    predicted_df[movieId] = movs
    predicted_df[userId] = Id
    predicted_df['est'] = predicted_df[movieId].apply(lambda x: round(algo.predict(Id,x).est,2))
    predicted_df = predicted_df.sort_values(by='est', ascending=False)
    
    if n >= samples:
        predicted_df = pd.merge(predicted_df,movie_titles,on=movieId)
        return predicted_df[[userId,'title_year','est']]
    else:
        predicted_df = predicted_df.head(n)
        predicted_df = pd.merge(predicted_df,movie_titles,on=movieId)
        return predicted_df[[userId,'title_year','est']]

# %%
predicted_top_n(1250, 'movieId', 10, None, df=ratings, userId='userId', algo=algo)
# Out:
#    userId                                         title_year   est
# 0    1250                                   Gladiator (2000)  4.61
# 1    1250                           Life Is Beautiful (1997)  4.57
# 2    1250                             The Sixth Sense (1999)  4.52
# 3    1250                       The Dark Knight Rises (2012)  4.49
# 4    1250                                Interstellar (2014)  4.43
# 5    1250  Harry Potter and the Deathly Hallows: Part 2 (...  4.41
# 6    1250                              The Green Mile (1999)  4.40
# 7    1250                         Pride and Prejudice (1995)  4.40
# 8    1250                                       Crash (2004)  4.39
# 9    1250                        The Bourne Ultimatum (2007)  4.39

# %% [markdown]
# # 3. Hybrid Recommender
#
# Great! Now we can return all movies with estimated ratings. Now what we're going to do is go back to our big dataframe with plots and all, recommend a movie based on cosine similarity, then return the results with estimated ratings!
#
# Note, at least for this first one, I am NOT taking into account that a user has watched a movie before.

# %%
movies.head()
# Out:
#                            title_year  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         bag_of_words  imdbId  movieId   tmdbId
# 0  g g johnlasseter animation  adventure  comedy ...  114709        1    862.0
# 1  pg pg jonathanhensleigh adventure  comedy  fam...  113497        2   8844.0
# 2  pg13 markstevenjohnson markstevenjohnson comed...  113228        3  15602.0
# 3  r terrymcmillan comedy  drama  romance forestw...  114885        4  31357.0
# 4  pg pg alberthackett comedy  family  romance ch...  113041        5  11862.0

# %%
test.head()
# Out:
#                            title_year  rated  imdbId  \
# 0                    Toy Story (1995)      G  114709
# 1                      Jumanji (1995)     PG  113497
# 2             Grumpier Old Men (1995)  PG-13  113228
# 3            Waiting to Exhale (1995)      R  114885
# 4  Father of the Bride Part II (1995)     PG  113041
#
#                                            genre         director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2  Mark Steven Johnson (characters), Mark Steven ...
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                    language country  movieId   tmdbId  year
# 0                   English     USA        1    862.0  1995
# 1           English, French     USA        2   8844.0  1995
# 2  English, Italian, German     USA        3  15602.0  1995
# 3                   English     USA        4  31357.0  1995
# 4                   English     USA        5  11862.0  1995

# %%
def new_movie_rec(title, Id, n, df=ratings, userId='userId', movieId='movieId', algo=algo, cosine_sim=cosine_sim):
    '''
    Returns movies by cosine similarity, with the user's estimated rating of them attached.
    '''
    
    recommended_movies = []

    # Grab the indices for the top 100 movies by cosine similarity
    idx = indices[indices == title].index[0]
    score_series = pd.Series(cosine_sim[3124]).sort_values(ascending = False)
    ordered_indices = list(score_series.iloc[1:100].index) # Filtering out itself
    for i in ordered_indices:
            recommended_movies.append(list(movies.index)[i])
        
    # Next, build the dataframe for these movies
    # Using 'movies' dataframe from earlier
    title_a = recommendations(title)
    title_recs = movies.loc[title_a].reset_index(inplace=False)
    title_recs = title_recs.set_index('title_year')
    
    # Predict the user ratings and sort by those ratings
    movs = title_recs[movieId].unique()
    title_recs['est'] = title_recs[movieId].apply(lambda x: round(algo.predict(Id,x).est,2))
    title_recs = title_recs.sort_values(by='est', ascending=False)
    
    # Finally, return n movies in the list
    if n == None:
        title_recs = title_recs[['est']]
        pretty_df = pd.merge(title_recs,test,on='title_year')
    elif n == 0:
        title_recs = title_recs[['est']]
        pretty_df = pd.merge(title_recs,test,on='title_year')
    else:
        title_recs = title_recs[['est']].head(n)
        pretty_df = pd.merge(title_recs,test,on='title_year')
    return pretty_df[['title_year','rated','year','genre','director','plot','language','country','est']]

# %%
new_movie_rec('Spirited Away (2001)', 1250, 10)
# Out:
#                                         title_year rated  year  \
# 0     Harry Potter and the Sorcerer's Stone (2001)    PG  2001
# 1                                     Shrek (2001)    PG  2001
# 2  Harry Potter and the Prisoner of Azkaban (2004)    PG  2004
# 3    Harry Potter and the Half-Blood Prince (2009)    PG  2009
# 4                                   Shrek 2 (2004)    PG  2004
# 5                           Song of the Sea (2014)    PG  2014
# 6                      Howl's Moving Castle (2004)    PG  2004
# 7                           The Incredibles (2004)    PG  2004
# 8                                   Tangled (2010)    PG  2010
# 9                   Kiki's Delivery Service (1989)     G  1989
#
#                                                genre  \
# 0                         Adventure, Family, Fantasy
# 1      Animation, Adventure, Comedy, Family, Fantasy
# 2                Adventure, Family, Fantasy, Mystery
# 3                Adventure, Family, Fantasy, Mystery
# 4  Animation, Adventure, Comedy, Family, Fantasy,...
# 5       Animation, Adventure, Drama, Family, Fantasy
# 6              Animation, Adventure, Family, Fantasy
# 7               Animation, Action, Adventure, Family
# 8  Animation, Adventure, Comedy, Family, Fantasy,...
# 9       Animation, Adventure, Drama, Family, Fantasy
#
#                                       director  \
# 0                               Chris Columbus
# 1                 Andrew Adamson, Vicky Jenson
# 2                               Alfonso Cuarón
# 3                                  David Yates
# 4  Andrew Adamson, Kelly Asbury, Conrad Vernon
# 5                                   Tomm Moore
# 6                               Hayao Miyazaki
# 7                                    Brad Bird
# 8                   Nathan Greno, Byron Howard
# 9                               Hayao Miyazaki
#
#                                                 plot           language  \
# 0  An orphaned boy enrolls in a school of wizardr...            English
# 1  A mean lord exiles fairytale creatures to the ...            English
# 2  It's Harry's third year at Hogwarts; not only ...            English
# 3  As Harry Potter begins his sixth year at Hogwa...            English
# 4  Princess Fiona's parents invite her and Shrek ...            English
# 5  Ben, a young Irish boy, and his little sister ...     English, Irish
# 6  When an unconfident young woman is cursed with...           Japanese
# 7  A family of undercover superheroes, while tryi...    English, French
# 8  The magically long-haired Rapunzel has spent h...            English
# 9  A young witch, on her mandatory year of indepe...  Japanese, English
#
#                                          country   est
# 0                                        UK, USA  4.31
# 1                                            USA  4.27
# 2                                        UK, USA  4.24
# 3                                        UK, USA  4.23
# 4                                            USA  4.12
# 5  Ireland, Denmark, Belgium, Luxembourg, France  4.08
# 6                                          Japan  4.05
# 7                                            USA  3.97
# 8                                            USA  3.89
# 9                                          Japan  3.86

# %%
new_movie_rec('Spirited Away (2001)', 118205, 10)
# Out:
#                                   title_year rated  year  \
# 0                  My Neighbor Totoro (1988)     G  1988
# 1                     Song of the Sea (2014)    PG  2014
# 2                Howl's Moving Castle (2004)    PG  2004
# 3             Kiki's Delivery Service (1989)     G  1989
# 4                               Shrek (2001)    PG  2001
# 5  Nausicaä of the Valley of the Wind (1984)    PG  1984
# 6                     The Incredibles (2004)    PG  2004
# 7                   Castle in the Sky (1986)    PG  1986
# 8     The Tale of The Princess Kaguya (2013)    PG  2013
# 9                         Porco Rosso (1992)    PG  1992
#
#                                             genre  \
# 0                      Animation, Family, Fantasy
# 1    Animation, Adventure, Drama, Family, Fantasy
# 2           Animation, Adventure, Family, Fantasy
# 3    Animation, Adventure, Drama, Family, Fantasy
# 4   Animation, Adventure, Comedy, Family, Fantasy
# 5           Animation, Adventure, Fantasy, Sci-Fi
# 6            Animation, Action, Adventure, Family
# 7    Animation, Adventure, Drama, Fantasy, Sci-Fi
# 8    Animation, Adventure, Drama, Family, Fantasy
# 9  Animation, Adventure, Comedy, Fantasy, Romance
#
#                        director  \
# 0                Hayao Miyazaki
# 1                    Tomm Moore
# 2                Hayao Miyazaki
# 3                Hayao Miyazaki
# 4  Andrew Adamson, Vicky Jenson
# 5                Hayao Miyazaki
# 6                     Brad Bird
# 7                Hayao Miyazaki
# 8                 Isao Takahata
# 9                Hayao Miyazaki
#
#                                                 plot           language  \
# 0  When two girls move to the country to be near ...           Japanese
# 1  Ben, a young Irish boy, and his little sister ...     English, Irish
# 2  When an unconfident young woman is cursed with...           Japanese
# 3  A young witch, on her mandatory year of indepe...  Japanese, English
# 4  A mean lord exiles fairytale creatures to the ...            English
# 5  Warrior and pacifist Princess Nausicaä despera...  Japanese, English
# 6  A family of undercover superheroes, while tryi...    English, French
# 7  A young boy and a girl with a magic crystal mu...           Japanese
# 8  Found inside a shining stalk of bamboo by an o...           Japanese
# 9  In 1930s Italy, a veteran World War I pilot is...           Japanese
#
#                                          country   est
# 0                                          Japan  3.95
# 1  Ireland, Denmark, Belgium, Luxembourg, France  3.84
# 2                                          Japan  3.83
# 3                                          Japan  3.80
# 4                                            USA  3.80
# 5                                     Japan, USA  3.75
# 6                                            USA  3.75
# 7                                          Japan  3.74
# 8                                          Japan  3.70
# 9                                          Japan  3.67

# %%
new_movie_rec('Mean Girls (2004)', 1250, 10)
# Out:
#                                   title_year  rated  year  \
# 0            Ferris Bueller's Day Off (1986)  PG-13  1986
# 1                Anne of Green Gables (1985)   TV-G  1985
# 2                        The Terminal (2004)  PG-13  2004
# 3                      50 First Dates (2004)  PG-13  2004
# 4           Forgetting Sarah Marshall (2008)      R  2008
# 5                        Bush's Brain (2004)  PG-13  2004
# 6              Some Kind of Wonderful (1987)  PG-13  1987
# 7                              Saved! (2004)  PG-13  2004
# 8                   Midnight in Paris (2011)  PG-13  2011
# 9  Nick and Norah's Infinite Playlist (2008)  PG-13  2008
#
#                            genre                      director  \
# 0                         Comedy                   John Hughes
# 1                  Drama, Family                           NaN
# 2         Comedy, Drama, Romance              Steven Spielberg
# 3         Comedy, Drama, Romance                   Peter Segal
# 4         Comedy, Drama, Romance              Nicholas Stoller
# 5                    Documentary  Joseph Mealey, Michael Shoob
# 6                 Drama, Romance                 Howard Deutch
# 7                  Comedy, Drama                Brian Dannelly
# 8       Comedy, Fantasy, Romance                   Woody Allen
# 9  Comedy, Drama, Music, Romance                 Peter Sollett
#
#                                                 plot  \
# 0  A high school wise guy is determined to have a...
# 1  An orphan girl, sent to an elderly brother and...
# 2  An Eastern European tourist unexpectedly finds...
# 3  Henry Roth is a man afraid of commitment up un...
# 4  Devastated Peter takes a Hawaiian vacation in ...
# 5  An examination of political consultant Karl Ro...
# 6  When Keith goes out with Amanda, the girl of h...
# 7  When a girl attending a Christian high school ...
# 8  While on a trip to Paris with his fiancée's fa...
# 9  High school student Nick O'Leary, member of th...
#
#                                             language  \
# 0                                    English, German
# 1                                            English
# 2  English, Bulgarian, Spanish, Russian, Mandarin...
# 3                  English, Hawaiian, Mandarin, None
# 4                English, Hawaiian, German, Japanese
# 5                                            English
# 6                                            English
# 7                                            English
# 8                   English, French, Spanish, German
# 9                                            English
#
#                      country   est
# 0                        USA  4.02
# 1  Canada, West Germany, USA  3.98
# 2                        USA  3.90
# 3                        USA  3.82
# 4                        USA  3.77
# 5                        USA  3.74
# 6                        USA  3.74
# 7                USA, Canada  3.74
# 8         Spain, USA, France  3.72
# 9                        USA  3.71

# %%
new_movie_rec('Mean Girls (2004)', 118205, 10)
# Out:
#                                 title_year     rated  year  \
# 0              Anne of Green Gables (1985)      TV-G  1985
# 1                 Midnight in Paris (2011)     PG-13  2011
# 2          Ferris Bueller's Day Off (1986)     PG-13  1986
# 3                The Winning Season (2009)     PG-13  2009
# 4                          Clueless (1995)     PG-13  1995
# 5  The Bachelor and the Bobby-Soxer (1947)  Approved  1947
# 6       Scott Pilgrim vs. the World (2010)     PG-13  2010
# 7                       Enough Said (2013)     PG-13  2013
# 8                Three O'Clock High (1987)     PG-13  1987
# 9                      The Terminal (2004)     PG-13  2004
#
#                               genre           director  \
# 0                     Drama, Family                NaN
# 1          Comedy, Fantasy, Romance        Woody Allen
# 2                            Comedy        John Hughes
# 3                     Comedy, Sport        Jim Strouse
# 4                   Comedy, Romance     Amy Heckerling
# 5                   Comedy, Romance        Irving Reis
# 6  Action, Comedy, Fantasy, Romance       Edgar Wright
# 7            Comedy, Drama, Romance  Nicole Holofcener
# 8                            Comedy        Phil Joanou
# 9            Comedy, Drama, Romance   Steven Spielberg
#
#                                                 plot  \
# 0  An orphan girl, sent to an elderly brother and...
# 1  While on a trip to Paris with his fiancée's fa...
# 2  A high school wise guy is determined to have a...
# 3  A comedy centered on a has-been coach who is g...
# 4  A rich high school student tries to boost a ne...
# 5  A high school girl falls for a playboy artist,...
# 6  Scott Pilgrim must defeat his new girlfriend's...
# 7  A divorced woman who decides to pursue the man...
# 8  A nerd gets himself in hot water with the new ...
# 9  An Eastern European tourist unexpectedly finds...
#
#                                             language  \
# 0                                            English
# 1                   English, French, Spanish, German
# 2                                    English, German
# 3                                            English
# 4                                   English, Spanish
# 5                                    English, French
# 6                                            English
# 7                                            English
# 8                                            English
# 9  English, Bulgarian, Spanish, Russian, Mandarin...
#
#                      country   est
# 0  Canada, West Germany, USA  3.93
# 1         Spain, USA, France  3.79
# 2                        USA  3.78
# 3                        USA  3.67
# 4                        USA  3.53
# 5                        USA  3.52
# 6     USA, UK, Canada, Japan  3.49
# 7                        USA  3.48
# 8                        USA  3.47
# 9                        USA  3.47

# %% [markdown]
# # 4. Unwatched Movies Only
#
# Finally, let's make a recommender that only returns movies the user hasn't before watched.

# %%
movies_df = test.copy()

# %%
movies_df.head()
# Out:
#                            title_year  rated  imdbId  \
# 0                    Toy Story (1995)      G  114709
# 1                      Jumanji (1995)     PG  113497
# 2             Grumpier Old Men (1995)  PG-13  113228
# 3            Waiting to Exhale (1995)      R  114885
# 4  Father of the Bride Part II (1995)     PG  113041
#
#                                            genre         director  \
# 0  Animation, Adventure, Comedy, Family, Fantasy    John Lasseter
# 1             Adventure, Comedy, Family, Fantasy     Joe Johnston
# 2                                Comedy, Romance    Howard Deutch
# 3                         Comedy, Drama, Romance  Forest Whitaker
# 4                        Comedy, Family, Romance    Charles Shyer
#
#                                               writer  \
# 0  John Lasseter (original story by), Pete Docter...
# 1  Jonathan Hensleigh (screenplay by), Greg Taylo...
# 2  Mark Steven Johnson (characters), Mark Steven ...
# 3  Terry McMillan (novel), Terry McMillan (screen...
# 4  Albert Hackett (screenplay "Father's Little Di...
#
#                                               actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
# 2  Walter Matthau, Jack Lemmon, Sophia Loren, Ann...
# 3  Whitney Houston, Angela Bassett, Loretta Devin...
# 4  Steve Martin, Diane Keaton, Martin Short, Kimb...
#
#                                                 plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with the pregn...
#
#                    language country  movieId   tmdbId  year
# 0                   English     USA        1    862.0  1995
# 1           English, French     USA        2   8844.0  1995
# 2  English, Italian, German     USA        3  15602.0  1995
# 3                   English     USA        4  31357.0  1995
# 4                   English     USA        5  11862.0  1995

# %%
def rec_unwatched(title, Id, n, df=ratings, userId='userId', movieId='movieId', algo=algo, cosine_sim=cosine_sim):
    '''
    Returns movies by cosine similarity, with the user's estimated rating of them attached.
    '''
    
    recommended_movies = []

    # Grab the indices for the top 100 movies by cosine similarity
    idx = indices[indices == title].index[0]
    score_series = pd.Series(cosine_sim[3124]).sort_values(ascending = False)
    ordered_indices = list(score_series.iloc[1:100].index) # Filtering out itself
    for i in ordered_indices:
            recommended_movies.append(list(movies.index)[i])
        
    # Next, build the dataframe for these movies
    # Using 'movies' dataframe from earlier
    title_a = recommendations(title)
    title_recs = movies.loc[title_a].reset_index(inplace=False)
    title_recs = title_recs.set_index('title_year')
    
    # Get rid of movies the user has previously seen
    sim_movs = title_recs[movieId].unique()
    temp_df = df[df[userId] == Id]
    watched_movs = temp_df[movieId].unique()
    unwatched = np.setdiff1d(sim_movs,watched_movs)
    
    new_movs = pd.DataFrame()
    new_movs['movieId'] = unwatched
    new_movs['est'] = new_movs[movieId].apply(lambda x: round(algo.predict(Id,x).est,2))
    new_movs = pd.merge(new_movs,movies_df,on='movieId')

    new_movs = new_movs.sort_values(by='est', ascending=False)
    new_movs = new_movs.set_index('title_year')
    
    # Finally, return n movies in the list
    if n == None:
        return new_movs[['rated','year','genre','director','plot','language','country','est']].dropna()
    elif n == 0:
        return new_movs[['rated','year','genre','director','plot','language','country','est']].dropna()
    else:
        return new_movs[['rated','year','genre','director','plot','language','country','est']].dropna().head(n)

# %%
rec_unwatched('Se7en (1995)', 118205, 10)
# Out:
#                                    rated  year  \
# title_year
# Citizen X (1995)                       R  1995
# The Crimson Kimono (1959)       APPROVED  1959
# Maniac Cop 2 (1990)                    R  1990
# Far from Home (1989)                   R  1989
# B.T.K. (2008)                          R  2008
# Whistling in Brooklyn (1943)      PASSED  1943
# The Frozen Ground (2013)               R  2013
# Lila & Eve (2015)                      R  2015
# The Nature of the Beast (1995)         R  1995
# Enduring Love (2004)                   R  2004
#
#                                                                             genre  \
# title_year
# Citizen X (1995)                       Biography, Crime, Drama, History, Thriller
# The Crimson Kimono (1959)                                   Crime, Drama, Mystery
# Maniac Cop 2 (1990)                               Crime, Horror, Action, Thriller
# Far from Home (1989)                              Crime, Drama, Mystery, Thriller
# B.T.K. (2008)                   Biography, Crime, Drama, Horror, Mystery, Thri...
# Whistling in Brooklyn (1943)                               Comedy, Crime, Mystery
# The Frozen Ground (2013)                          Crime, Drama, Mystery, Thriller
# Lila & Eve (2015)                                 Crime, Drama, Mystery, Thriller
# The Nature of the Beast (1995)                           Crime, Mystery, Thriller
# Enduring Love (2004)                            Drama, Mystery, Romance, Thriller
#
#                                          director  \
# title_year
# Citizen X (1995)                    Chris Gerolmo
# The Crimson Kimono (1959)           Samuel Fuller
# Maniac Cop 2 (1990)                William Lustig
# Far from Home (1989)                  Meiert Avis
# B.T.K. (2008)                      Michael Feifer
# Whistling in Brooklyn (1943)      S. Sylvan Simon
# The Frozen Ground (2013)             Scott Walker
# Lila & Eve (2015)               Charles Stone III
# The Nature of the Beast (1995)       Victor Salva
# Enduring Love (2004)                Roger Michell
#
#                                                                              plot  \
# title_year
# Citizen X (1995)                During the 1980s, Soviet authorities hunt for ...
# The Crimson Kimono (1959)       Two detectives seek a stripper's killer in the...
# Maniac Cop 2 (1990)             A supernatural, maniac killer cop teams up wit...
# Far from Home (1989)            A teenage girl and her father driving cross-co...
# B.T.K. (2008)                   Inspired by the real-life serial killer, B.T.K...
# Whistling in Brooklyn (1943)    Radio crime show host "The Fox" finds himself ...
# The Frozen Ground (2013)        An Alaska State Trooper partners with a young ...
# Lila & Eve (2015)               Two distraught mothers, whose children were gu...
# The Nature of the Beast (1995)  Two men, both hiding a deadly secret, are on a...
# Enduring Love (2004)            Two strangers become dangerously close after w...
#
#                                          language       country   est
# title_year
# Citizen X (1995)                          English  USA, Hungary  3.81
# The Crimson Kimono (1959)       English, Japanese           USA  3.41
# Maniac Cop 2 (1990)                       English           USA  3.38
# Far from Home (1989)                      English           USA  3.37
# B.T.K. (2008)                             English           USA  3.36
# Whistling in Brooklyn (1943)              English           USA  3.31
# The Frozen Ground (2013)          English, French           USA  3.30
# Lila & Eve (2015)                         English           USA  3.29
# The Nature of the Beast (1995)            English   USA, Canada  3.28
# Enduring Love (2004)                      English            UK  3.23

# %%
new_movie_rec('Se7en (1995)', 118205, 10)
# Out:
#                            title_year      rated  year  \
# 0  Witness for the Prosecution (1957)  Not Rated  1957
# 1     And Then There Were None (1945)   Approved  1945
# 2         The Spiral Staircase (1946)   Approved  1946
# 3                    Citizen X (1995)          R  1995
# 4                         Rope (1948)         PG  1948
# 5           The Last of Sheila (1973)         PG  1973
# 6          Mississippi Burning (1988)          R  1988
# 7                      Monster (2003)          R  2003
# 8               Gone Baby Gone (2007)          R  2007
# 9            Dolores Claiborne (1995)          R  1995
#
#                                         genre          director  \
# 0             Crime, Drama, Mystery, Thriller      Billy Wilder
# 1             Crime, Drama, Mystery, Thriller        René Clair
# 2                    Drama, Mystery, Thriller    Robert Siodmak
# 3  Biography, Crime, Drama, History, Thriller     Chris Gerolmo
# 4             Crime, Drama, Mystery, Thriller  Alfred Hitchcock
# 5             Crime, Drama, Mystery, Thriller      Herbert Ross
# 6    Crime, Drama, History, Mystery, Thriller       Alan Parker
# 7           Biography, Crime, Drama, Thriller     Patty Jenkins
# 8             Crime, Drama, Mystery, Thriller       Ben Affleck
# 9             Crime, Drama, Mystery, Thriller   Taylor Hackford
#
#                                                 plot         language  \
# 0  A veteran British barrister must defend his cl...  English, German
# 1  Seven guests, a newly hired personal secretary...          English
# 2  In 1916, a shadowy serial killer is targeting ...          English
# 3  During the 1980s, Soviet authorities hunt for ...          English
# 4  Two men attempt to prove they committed the pe...          English
# 5  A year after Sheila is killed in a hit-and-run...  English, French
# 6  Two F.B.I. Agents, with wildly different style...          English
# 7  Based on the life of Aileen Wuornos, a Daytona...          English
# 8  Two Boston area detectives investigate a littl...          English
# 9  A big-city reporter travels to the small town ...          English
#
#         country   est
# 0           USA  4.07
# 1           USA  3.91
# 2           USA  3.83
# 3  USA, Hungary  3.81
# 4           USA  3.81
# 5           USA  3.77
# 6           USA  3.77
# 7  Germany, USA  3.74
# 8           USA  3.73
# 9           USA  3.66

# %%
new_movie_rec('Spirited Away (2001)', 118205, 10)
# Out:
#                                   title_year rated  year  \
# 0                  My Neighbor Totoro (1988)     G  1988
# 1                     Song of the Sea (2014)    PG  2014
# 2                Howl's Moving Castle (2004)    PG  2004
# 3             Kiki's Delivery Service (1989)     G  1989
# 4                               Shrek (2001)    PG  2001
# 5  Nausicaä of the Valley of the Wind (1984)    PG  1984
# 6                     The Incredibles (2004)    PG  2004
# 7                   Castle in the Sky (1986)    PG  1986
# 8     The Tale of The Princess Kaguya (2013)    PG  2013
# 9                         Porco Rosso (1992)    PG  1992
#
#                                             genre  \
# 0                      Animation, Family, Fantasy
# 1    Animation, Adventure, Drama, Family, Fantasy
# 2           Animation, Adventure, Family, Fantasy
# 3    Animation, Adventure, Drama, Family, Fantasy
# 4   Animation, Adventure, Comedy, Family, Fantasy
# 5           Animation, Adventure, Fantasy, Sci-Fi
# 6            Animation, Action, Adventure, Family
# 7    Animation, Adventure, Drama, Fantasy, Sci-Fi
# 8    Animation, Adventure, Drama, Family, Fantasy
# 9  Animation, Adventure, Comedy, Fantasy, Romance
#
#                        director  \
# 0                Hayao Miyazaki
# 1                    Tomm Moore
# 2                Hayao Miyazaki
# 3                Hayao Miyazaki
# 4  Andrew Adamson, Vicky Jenson
# 5                Hayao Miyazaki
# 6                     Brad Bird
# 7                Hayao Miyazaki
# 8                 Isao Takahata
# 9                Hayao Miyazaki
#
#                                                 plot           language  \
# 0  When two girls move to the country to be near ...           Japanese
# 1  Ben, a young Irish boy, and his little sister ...     English, Irish
# 2  When an unconfident young woman is cursed with...           Japanese
# 3  A young witch, on her mandatory year of indepe...  Japanese, English
# 4  A mean lord exiles fairytale creatures to the ...            English
# 5  Warrior and pacifist Princess Nausicaä despera...  Japanese, English
# 6  A family of undercover superheroes, while tryi...    English, French
# 7  A young boy and a girl with a magic crystal mu...           Japanese
# 8  Found inside a shining stalk of bamboo by an o...           Japanese
# 9  In 1930s Italy, a veteran World War I pilot is...           Japanese
#
#                                          country   est
# 0                                          Japan  3.95
# 1  Ireland, Denmark, Belgium, Luxembourg, France  3.84
# 2                                          Japan  3.83
# 3                                          Japan  3.80
# 4                                            USA  3.80
# 5                                     Japan, USA  3.75
# 6                                            USA  3.75
# 7                                          Japan  3.74
# 8                                          Japan  3.70
# 9                                          Japan  3.67

# %%
rec_unwatched('Spirited Away (2001)', 118205, 10)
# Out:
#                                           rated  year  \
# title_year
# Song of the Sea (2014)                       PG  2014
# Nausicaä of the Valley of the Wind (1984)    PG  1984
# The Tale of The Princess Kaguya (2013)       PG  2013
# Porco Rosso (1992)                           PG  1992
# Millennium Actress (2001)                    PG  2001
# Ponyo (2008)                                  G  2008
# The Cat Returns (2002)                        G  2002
# Rise of the Guardians (2012)                 PG  2012
# My Neighbors the Yamadas (1999)              PG  1999
# Pom Poko (1994)                              PG  1994
#
#                                                                                        genre  \
# title_year
# Song of the Sea (2014)                          Animation, Adventure, Drama, Family, Fantasy
# Nausicaä of the Valley of the Wind (1984)              Animation, Adventure, Fantasy, Sci-Fi
# The Tale of The Princess Kaguya (2013)          Animation, Adventure, Drama, Family, Fantasy
# Porco Rosso (1992)                            Animation, Adventure, Comedy, Fantasy, Romance
# Millennium Actress (2001)                                 Animation, Drama, Fantasy, Romance
# Ponyo (2008)                                   Animation, Adventure, Comedy, Family, Fantasy
# The Cat Returns (2002)                     Animation, Adventure, Comedy, Family, Fantasy,...
# Rise of the Guardians (2012)               Animation, Action, Adventure, Comedy, Family, ...
# My Neighbors the Yamadas (1999)                                    Animation, Comedy, Family
# Pom Poko (1994)                                    Animation, Comedy, Drama, Family, Fantasy
#
#                                                   director  \
# title_year
# Song of the Sea (2014)                          Tomm Moore
# Nausicaä of the Valley of the Wind (1984)   Hayao Miyazaki
# The Tale of The Princess Kaguya (2013)       Isao Takahata
# Porco Rosso (1992)                          Hayao Miyazaki
# Millennium Actress (2001)                      Satoshi Kon
# Ponyo (2008)                                Hayao Miyazaki
# The Cat Returns (2002)                     Hiroyuki Morita
# Rise of the Guardians (2012)                  Peter Ramsey
# My Neighbors the Yamadas (1999)              Isao Takahata
# Pom Poko (1994)                              Isao Takahata
#
#                                                                                         plot  \
# title_year
# Song of the Sea (2014)                     Ben, a young Irish boy, and his little sister ...
# Nausicaä of the Valley of the Wind (1984)  Warrior and pacifist Princess Nausicaä despera...
# The Tale of The Princess Kaguya (2013)     Found inside a shining stalk of bamboo by an o...
# Porco Rosso (1992)                         In 1930s Italy, a veteran World War I pilot is...
# Millennium Actress (2001)                  A TV interviewer and his cameraman meet a form...
# Ponyo (2008)                               A five-year-old boy develops a relationship wi...
# The Cat Returns (2002)                     After helping a cat, a 17-year-old girl finds ...
# Rise of the Guardians (2012)               When the evil spirit Pitch launches an assault...
# My Neighbors the Yamadas (1999)            The life and misadventures of a family in cont...
# Pom Poko (1994)                            A community of magical shape-shifting raccoon ...
#
#                                                     language  \
# title_year
# Song of the Sea (2014)                        English, Irish
# Nausicaä of the Valley of the Wind (1984)  Japanese, English
# The Tale of The Princess Kaguya (2013)              Japanese
# Porco Rosso (1992)                                  Japanese
# Millennium Actress (2001)                  Japanese, English
# Ponyo (2008)                                        Japanese
# The Cat Returns (2002)                     Japanese, English
# Rise of the Guardians (2012)                 English, French
# My Neighbors the Yamadas (1999)                     Japanese
# Pom Poko (1994)                            Japanese, English
#
#                                                                                  country  \
# title_year
# Song of the Sea (2014)                     Ireland, Denmark, Belgium, Luxembourg, France
# Nausicaä of the Valley of the Wind (1984)                                     Japan, USA
# The Tale of The Princess Kaguya (2013)                                             Japan
# Porco Rosso (1992)                                                                 Japan
# Millennium Actress (2001)                                                          Japan
# Ponyo (2008)                                                                       Japan
# The Cat Returns (2002)                                                             Japan
# Rise of the Guardians (2012)                                                         USA
# My Neighbors the Yamadas (1999)                                                    Japan
# Pom Poko (1994)                                                                    Japan
#
#                                             est
# title_year
# Song of the Sea (2014)                     3.84
# Nausicaä of the Valley of the Wind (1984)  3.75
# The Tale of The Princess Kaguya (2013)     3.70
# Porco Rosso (1992)                         3.67
# Millennium Actress (2001)                  3.65
# Ponyo (2008)                               3.62
# The Cat Returns (2002)                     3.57
# Rise of the Guardians (2012)               3.52
# My Neighbors the Yamadas (1999)            3.51
# Pom Poko (1994)                            3.49
